# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set()

# %% [markdown]
# # **Q-learning :**

# %%
# Carte 1 :
rewards_carte1_qlearning = np.loadtxt("./tests/Q_learning_Epsilon_Greedy_1_rewards.csv")
actions_carte1_qlearning = np.loadtxt("./tests/Q_learning_Epsilon_Greedy_1_actions.csv")
# time :  0.3377840518951416

# %%
# Carte 3 :
rewards_carte3_qlearning = np.loadtxt("./tests/Q_learning_Epsilon_Greedy_3_rewards.csv")
actions_carte3_qlearning = np.loadtxt("./tests/Q_learning_Epsilon_Greedy_3_actions.csv")
#time :  0.3254706859588623

# %%
# Carte 6 :
rewards_carte6_qlearning = np.loadtxt("./tests/Q_learning_Epsilon_Greedy_6_rewards.csv")
actions_carte6_qlearning = np.loadtxt("./tests/Q_learning_Epsilon_Greedy_6_actions.csv")
#time :  0.450148344039917

# %%
# Carte 7 :
rewards_carte7_qlearning = np.loadtxt("./tests/Q_learning_Epsilon_Greedy_7_rewards.csv")
actions_carte7_qlearning = np.loadtxt("./tests/Q_learning_Epsilon_Greedy_7_actions.csv")
#time :  6.320305585861206

# %% [markdown]
# # **SARSA :**

# %%
# Carte 1 :
rewards_carte1_sarsa = np.loadtxt("./tests/SARSA_Epsilon_Greedy_1_rewards.csv")
actions_carte1_sarsa = np.loadtxt("./tests/SARSA_Epsilon_Greedy_1_actions.csv")
#time :  0.2573690414428711

# %%
# Carte 3 :
rewards_carte3_sarsa = np.loadtxt("./tests/SARSA_Epsilon_Greedy_3_rewards.csv")
actions_carte3_sarsa = np.loadtxt("./tests/SARSA_Epsilon_Greedy_3_actions.csv")
# time :  0.20265507698059082

# %%
# Carte 6 :
rewards_carte6_sarsa = np.loadtxt("./tests/SARSA_Epsilon_Greedy_6_rewards.csv")
actions_carte6_sarsa = np.loadtxt("./tests/SARSA_Epsilon_Greedy_6_actions.csv")
# time :  0.35352516174316406

# %%
# Carte 11 :
rewards_carte7_sarsa = np.loadtxt("./tests/SARSA_Epsilon_Greedy_7_rewards.csv")
actions_carte7_sarsa = np.loadtxt("./tests/SARSA_Epsilon_Greedy_7_actions.csv")
# time :  8.108861684799194

# %% [markdown]
# # **Dyna-Q :**

# %%
# Carte 1 :
rewards_carte1_dynaq = np.loadtxt("./tests/Dyna_Q_Epsilon_Greedy_1_rewards.csv")
actions_carte1_dynaq = np.loadtxt("./tests/Dyna_Q_Epsilon_Greedy_1_actions.csv")
# time 16.009615421295166

# %%
# Carte 3 :
rewards_carte3_dynaq = np.loadtxt("./tests/Dyna_Q_Epsilon_Greedy_3_rewards.csv")
actions_carte3_dynaq = np.loadtxt("./tests/Dyna_Q_Epsilon_Greedy_3_actions.csv")
# time :  7.433191299438477

# %%
# Carte 6 :
rewards_carte6_dynaq = np.loadtxt("./tests/Dyna_Q_Epsilon_Greedy_6_rewards.csv")
actions_carte6_dynaq = np.loadtxt("./tests/Dyna_Q_Epsilon_Greedy_6_actions.csv")
# time :  28.578809022903442

# %%
# Carte 7 :
rewards_carte7_dynaq = np.loadtxt("./tests/Dyna_Q_Epsilon_Greedy_7_rewards.csv")
actions_carte7_dynaq = np.loadtxt("./tests/Dyna_Q_Epsilon_Greedy_7_actions.csv")
# time :  342.50226044654846

# %% [markdown]
# # 1 - Carte 1 :

# %%
epochs = np.arange(1, rewards_carte1_qlearning.shape[0]+1)
plt.title("Reward cumulé moyen - Carte 1")
plt.xlabel("Épisodes")
plt.ylabel("Reward cumulé moyen")
plt.plot(np.cumsum(rewards_carte1_qlearning) / epochs, label='Q-lerning')
plt.plot(np.cumsum(rewards_carte1_sarsa) / epochs, label='SARSA')
plt.plot(np.cumsum(rewards_carte1_dynaq) / epochs, label='Dyna-Q')
plt.legend()
plt.savefig("./graphes/comparaison_carte1.png")

# %%
epochs = np.arange(1, rewards_carte1_qlearning.shape[0]+1)
plt.title("Nb actions cumulé moyen - Carte 1")
plt.xlabel("Épisodes")
plt.ylabel("Nb actions cumulé moyen")
plt.plot(np.cumsum(actions_carte1_qlearning) / epochs, label='Q-lerning')
plt.plot(np.cumsum(actions_carte1_sarsa) / epochs, label='SARSA')
plt.plot(np.cumsum(actions_carte1_dynaq) / epochs, label='Dyna-Q')
plt.legend()
plt.savefig("./graphes/actions_carte1.png")

# %% [markdown]
# # 2 - Carte 3 :

# %%
epochs = np.arange(1, rewards_carte1_qlearning.shape[0]+1)
plt.title("Reward cumulé moyen - Carte 3")
plt.xlabel("Épisodes")
plt.ylabel("Reward cumulé moyen")
plt.plot(np.cumsum(rewards_carte3_qlearning) / epochs, label='Q-lerning')
plt.plot(np.cumsum(rewards_carte3_sarsa) / epochs, label='SARSA')
plt.plot(np.cumsum(rewards_carte3_dynaq) / epochs, label='Dyna-Q')
plt.legend()
plt.savefig("./graphes/comparaison_carte3.png")

# %%
epochs = np.arange(1, rewards_carte1_qlearning.shape[0]+1)
plt.title("Nb actions cumulé moyen - Carte 3")
plt.xlabel("Épisodes")
plt.ylabel("Nb actions cumulé moyen")
plt.plot(np.cumsum(actions_carte3_qlearning) / epochs, label='Q-lerning')
plt.plot(np.cumsum(actions_carte3_sarsa) / epochs, label='SARSA')
plt.plot(np.cumsum(actions_carte3_dynaq) / epochs, label='Dyna-Q')
plt.legend()
plt.savefig("./graphes/actions_carte3.png")

# %% [markdown]
# # 3 - Carte 6 :

# %%
epochs = np.arange(1, rewards_carte1_qlearning.shape[0]+1)
plt.title("Reward cumulé moyen - Carte 6")
plt.xlabel("Épisodes")
plt.ylabel("Reward cumulé moyen")
plt.plot(np.cumsum(rewards_carte6_qlearning) / epochs, label='Q-lerning')
plt.plot(np.cumsum(rewards_carte6_sarsa) / epochs, label='SARSA')
plt.plot(np.cumsum(rewards_carte6_dynaq) / epochs, label='Dyna-Q')
plt.legend()
plt.savefig("./graphes/comparaison_carte6.png")

# %%
epochs = np.arange(1, rewards_carte1_qlearning.shape[0]+1)
plt.title("Nb actions cumulé moyen - Carte 6")
plt.xlabel("Épisodes")
plt.ylabel("Nb actions cumulé moyen")
plt.plot(np.cumsum(actions_carte6_qlearning) / epochs, label='Q-lerning')
plt.plot(np.cumsum(actions_carte6_sarsa) / epochs, label='SARSA')
plt.plot(np.cumsum(actions_carte6_dynaq) / epochs, label='Dyna-Q')
plt.legend()
plt.savefig("./graphes/actions_carte6.png")

# %% [markdown]
# # 3 - Carte 7 :

# %%
epochs = np.arange(1, rewards_carte1_qlearning.shape[0]+1)
plt.title("Reward cumulé moyen - Carte 7")
plt.xlabel("Épisodes")
plt.ylabel("Reward cumulé moyen")
plt.plot(np.cumsum(rewards_carte7_qlearning) / epochs, label='Q-lerning')
plt.plot(np.cumsum(rewards_carte7_sarsa) / epochs, label='SARSA')
plt.plot(np.cumsum(rewards_carte7_dynaq) / epochs, label='Dyna-Q')
plt.legend()
plt.savefig("./graphes/comparaison_carte7.png")

# %%
epochs = np.arange(1, rewards_carte1_qlearning.shape[0]+1)
plt.title("Nb actions cumulé moyen - Carte 7")
plt.xlabel("Épisodes")
plt.ylabel("Nb actions cumulé moyen")
plt.plot(np.cumsum(actions_carte7_qlearning) / epochs, label='Q-lerning')
plt.plot(np.cumsum(actions_carte7_sarsa) / epochs, label='SARSA')
plt.plot(np.cumsum(actions_carte7_dynaq) / epochs, label='Dyna-Q')
plt.legend()
plt.savefig("./graphes/actions_carte7.png")

# %% [markdown]
# # **Comparaison des strategies d'exploration sur Q-learning - Carte 7 :**

# %%
# Carte 7 boltzman :
rewards_carte7_qlearning_boltzman = np.loadtxt("./tests/Q_learning_Boltzman_7_rewards.csv")
actions_carte7_qlearning_boltzman = np.loadtxt("./tests/Q_learning_Boltzman_7_actions.csv")
# time :  18.249698400497437

# %%
# Carte 7 ucb :
rewards_carte7_qlearning_ucb = np.loadtxt("./tests/Q_learning_UCB_7_rewards.csv")
actions_carte7_qlearning_ucb = np.loadtxt("./tests/Q_learning_UCB_7_actions.csv")
# time :  1.0851237773895264

# %%
# Carte 7 greedy :
rewards_carte7_qlearning_Greedy = np.loadtxt("./tests/Q_learning_Greedy_7_rewards.csv")
actions_carte7_qlearning_Greedy = np.loadtxt("./tests/Q_learning_Greedy_7_actions.csv")
# time :  13.742878198623657

# %%
epochs = np.arange(1, rewards_carte1_qlearning.shape[0]+1)
plt.title("Reward cumulé moyen - Carte 7")
plt.xlabel("Épisodes")
plt.ylabel("Reward cumulé moyen")
plt.plot(np.cumsum(rewards_carte7_qlearning) / epochs, label='epsilon-Greedy')
plt.plot(np.cumsum(rewards_carte7_qlearning_boltzman) / epochs, label='Boltzman')
plt.plot(np.cumsum(rewards_carte7_qlearning_ucb) / epochs, label='UCB')
plt.legend()
plt.savefig("./graphes/rewards_strategies_carte7.png")

# %%
epochs = np.arange(1, rewards_carte1_qlearning.shape[0]+1)
plt.title("Nb actions cumulé moyen - Carte 7")
plt.xlabel("Épisodes")
plt.ylabel("Nb actions cumulé moyen")
plt.plot(np.cumsum(actions_carte7_qlearning) / epochs, label='epsilon-Greedy')
plt.plot(np.cumsum(actions_carte7_qlearning_boltzman) / epochs, label='Boltzman')
plt.plot(np.cumsum(actions_carte7_qlearning_ucb) / epochs, label='UCB')
plt.legend()
plt.savefig("./graphes/actions_strategies_carte7.png")
