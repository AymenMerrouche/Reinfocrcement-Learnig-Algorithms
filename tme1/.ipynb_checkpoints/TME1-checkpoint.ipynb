# %%
import re
import numpy as np
import pandas as pd
file = pd.read_csv("CTR.txt", sep=";|:", header = None, engine="python")
file.drop(columns=[0], inplace = True)

# %%
class Strategy:
    def __init__(self, N_ads):
        self.N_ads = N_ads
        self.rewards = np.zeros(N_ads)
        self.times = np.zeros(N_ads)
        pass
    def act(self, t):
        pass
    def update(self, t, choice, reward):
        self.rewards[choice] +=reward
        self.times[choice] += 1
        pass

# %%
class Env:
    def __init__(self, file):
        self.file = file
    def act(self, choice, t):
        return file[6+ choice][t]
    def getContext(self, t, a):
        return file[t][:5]
    def evaluate(self, strategy):
        rewards, regrets = [],[]
        choices, optimalchoices = [],[]
        for i , t in enumerate(range(0, len(self.file))):
            choice = strategy.act(t)
            reward, rewardBest = self.act(choice, t), self.file.loc[t][5:].values.max()
            choices.append( choice)
            optimalchoices.append(self.file.loc[t][5:].values.argmax())
            strategy.update(t, choice, reward)
            rewards.append(reward)
            regrets.append(rewardBest - reward)
        return np.cumsum(np.array(rewards)), np.cumsum(regrets), np.array(choices), np.array(optimalchoices)

# %%
import random
class Random(Strategy):
    def __init__(self, N_ads):
        super().__init__(N_ads)
        pass
    def act(self, t):
        return random.randint(0, self.N_ads-1)

# %%
class StaticBest(Strategy):
    def __init__(self, N_ads,env, k=0):
        super().__init__(N_ads)
        self.k = k
        self.times +=1
    def act(self, t):
        if self.k > 0:
            self.k -=1
            return random.randint(0,self.N_ads-1)
        else:
            values= self.rewards / self.times
            return np.random.choice( np.argwhere(values == np.max(values) ).reshape( -1))

# %%
class stat(Strategy):
    def __init__(self, N_ads,file):
        super().__init__(N_ads)
        self.choice = np.argmax(file.loc[:, 6:].mean(axis=0).to_numpy())
    def act(self, t):
        return self.choice

# %%
class epsilon_greedy(Strategy):
    def __init__(self, N_ads,env, epsilon= 0):
        super().__init__(N_ads)
        self.epsilon = epsilon
        self.times += 1
        #self.rewards += 0.5 
    def act(self, t):
        if  np.random.rand() < self.epsilon:
            return random.randint(0,self.N_ads-1)
        else: 
            values= self.rewards / self.times
            return np.random.choice( np.argwhere(values == np.max(values) ).reshape( -1))

# %%
class Optimal(Strategy):
    def __init__(self, N_ads, env):
        super().__init__(N_ads)
    def act(self, t):
        return env.file.loc[t, 6:].values.argmax()

# %%
class UCB(Strategy):
    def __init__(self, N_ads, env, factor = np.sqrt(2)):
        super().__init__(N_ads)
        self.factor = factor
        for i in range(N_ads):
            reward = env.act(i,i)
            self.update(i,i, reward)
    def act(self, t):
        t = self.times.sum()
        return np.argmax((self.rewards/self.times) +self.factor* np.sqrt(2*np.log(t)/self.times))

# %%
class linUCB(Strategy):
    def __init__(self, N_ads, d,alpha, env, file):
        super().__init__(N_ads)
        self.env, self.alpha = env, alpha
        self.A = {}
        self.B = {}
        self.theta = np.zeros(( d, N_ads))
        self.alpha = alpha
        self.file = file
        self.nb_arms = N_ads
    def act(self,t):
        p = np.zeros(self.nb_arms)
        for a in range(self.nb_arms):
            if a not in self.A.keys():
                self.A[a] = np.identity(5)
                self.B[a] = np.zeros(5)
            inv_a = np.linalg.inv(self.A[a])
            mu_hat_a = inv_a @ self.B[a]
            
            p_a = mu_hat_a.T @ self.file.loc[t, :5].values + self.alpha \
            * np.sqrt(self.file.loc[t, :5].values @ inv_a @ self.file.loc[t, :5].values)
            p[a] = p_a
        action = np.argmax(p)
        return action
    
    def update(self,t, action, reward):
        self.rewards[action] +=reward
        self.times[action] += 1
        self.A[action] = self.A[action] + (self.file.loc[t, :5].values @ self.file.loc[t, :5].values.T)
        self.B[action] = self.B[action] + (reward* self.file.loc[t, :5].values)

# %%
env = Env(file)
r =  Random(10)
#Greedy = StaticBest(10, env, k= 1)
EG = epsilon_greedy(10, env, epsilon= 0.3)
static = stat(10, file)
optimal = Optimal(10, env)
ucb = UCB(10,env, 0.5)
linUcb = linUCB(10, 5, 2.22,env, file)

# %%
gainsRandom, regretsRandom, Rchoices,Roptimal = env.evaluate(r)
#gainsGreedy, regretsGreedy, choicesGreedy, optimalchoicesGreedy = env.evaluate(Greedy)

gainsOptimal, regretsOptimal, ochoice,oochoice = env.evaluate(optimal)

gainsStatic, regretsStatic, choicesStatic,optimalchoicesStatic = env.evaluate(static)

# %%
gainsEG, regretsEG, choicesEG, optimalchoicesEG = env.evaluate(EG)

# %%
gainsUcb, regretsUcb, choicesUCB, optimalchoicesUCB = env.evaluate(ucb)

# %%
gainslinUcb, regretslinUcb,choiceslinUCB, optimalchoiceslinUCB = env.evaluate(linUcb)

# %%
results ={}
for delta in [2,3,4] :
    alpha = 1 + np.sqrt(np.log(2/delta)/2)
    results[delta] = {}
    model = linUcb = linUCB(10, 5, alpha ,env, file)
    a,b,c,d = env.evaluate(model)
    
    results[k]["gains"] = a
    results[k]["regrets"] = b
    results[k]["actions"] = c
    results[k]["actions_optimale"] = d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-d6b442759bcc> in <module>
#       6     a,b,c,d = env.evaluate(model)
#       7
# ----> 8     results[k]["gains"] = a
#       9     results[k]["regrets"] = b
#      10     results[k]["actions"] = c
#
# NameError: name 'k' is not defined

# %%
# Out:
# 0

# %%
for k in [1]:
    results[k] = {}
    model = epsilon_greedy(10, env, epsilon=k)
    a,b,c,d = env.evaluate(model)
    
    results[k]["gains"] = a
    results[k]["regrets"] = b
    results[k]["actions"] = c
    results[k]["actions_optimale"] = d

# %% [markdown]
# # Gains

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
1 + np.sqrt(np.log(2 / 0.2) / 2)
# Out:
# 2.0729830131446736

# %%
times = range(1, len(file)+1)
plt.plot(times,gainsRandom/ times, label= "Random")
plt.plot(times,gainsOptimal/ times, label= "Optimal")
plt.plot(times,gainsEG/ times, label= 'epsilon_greedy')
#plt.plot(times,gainsGreedy/ times, label= 'Greedy')
plt.plot(times,gainsStatic/ times, label= 'Static_best')
plt.plot(times,gainsUcb/ times, label= 'UCB')
plt.plot(times,gainslinUcb/ times, label= 'linUCB')
plt.xlabel("itération")
plt.ylabel("gains cumulés moyens")
plt.legend(loc = "best")

# %%
times = range(1, len(file)+1)
plt.plot(times,regretsRandom/ times, label= "Random")
plt.plot(times,regretsOptimal/ times, label= "Optimal")
plt.plot(times,regretsEG/ times, label= 'epsilon_greedy')
plt.plot(times,regretsStatic/ times, label= 'Static_best')
plt.plot(times,regretsUcb/ times, label= 'UCB')
plt.plot(times,regretslinUcb/ times, label= 'linUCB')
plt.xlabel("itération")
plt.ylabel("regrets cumulés moyens")
plt.legend(loc = "best")

# %%
times = range(1, len(file)+1)
plt.plot(times,np.cumsum(Rchoices == Roptimal)/ times, label= "Random")
plt.plot(times,np.cumsum(ochoice == oochoice)/ times, label= "Optimal")
plt.plot(times,np.cumsum(choicesEG == optimalchoicesEG)/times, label= 'epsilon_greedy')
plt.plot(times,np.cumsum(choicesStatic == optimalchoicesStatic)/ times, label= 'Static_best')
plt.plot(times,np.cumsum(choicesUCB == optimalchoicesUCB)/ times, label= 'UCB')
plt.plot(times,np.cumsum(choiceslinUCB== optimalchoiceslinUCB)/ times, label= 'linUCB')
plt.xlabel("itération")
plt.ylabel("% d'actions optimales")
plt.legend(loc = "upper right")

# %%
plt.boxplot(file.loc[:, 6:].to_numpy(),sym="")
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f6e767da8d0>,
#   <matplotlib.lines.Line2D at 0x7f6e767e5a50>,
#   <matplotlib.lines.Line2D at 0x7f6e767e5f90>,
#   <matplotlib.lines.Line2D at 0x7f6e76774910>,
#   <matplotlib.lines.Line2D at 0x7f6e76774e10>,
#   <matplotlib.lines.Line2D at 0x7f6e76785750>,
#   <matplotlib.lines.Line2D at 0x7f6e76785cd0>,
#   <matplotlib.lines.Line2D at 0x7f6e76796650>,
#   <matplotlib.lines.Line2D at 0x7f6e7679efd0>,
#   <matplotlib.lines.Line2D at 0x7f6e7677cd50>,
#   <matplotlib.lines.Line2D at 0x7f6e76730990>,
#   <matplotlib.lines.Line2D at 0x7f6e76730e50>,
#   <matplotlib.lines.Line2D at 0x7f6e7673ecd0>,
#   <matplotlib.lines.Line2D at 0x7f6e76737dd0>,
#   <matplotlib.lines.Line2D at 0x7f6e7674eb50>,
#   <matplotlib.lines.Line2D at 0x7f6e76747c50>,
#   <matplotlib.lines.Line2D at 0x7f6e7679eb10>,
#   <matplotlib.lines.Line2D at 0x7f6e76760e50>,
#   <matplotlib.lines.Line2D at 0x7f6e766ef790>,
#   <matplotlib.lines.Line2D at 0x7f6e766efc90>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f6e767e5f50>,
#   <matplotlib.lines.Line2D at 0x7f6e767da790>,
#   <matplotlib.lines.Line2D at 0x7f6e7676df10>,
#   <matplotlib.lines.Line2D at 0x7f6e7676d990>,
#   <matplotlib.lines.Line2D at 0x7f6e767857d0>,
#   <matplotlib.lines.Line2D at 0x7f6e7678c250>,
#   <matplotlib.lines.Line2D at 0x7f6e76796b50>,
#   <matplotlib.lines.Line2D at 0x7f6e7678cc50>,
#   <matplotlib.lines.Line2D at 0x7f6e767a5a10>,
#   <matplotlib.lines.Line2D at 0x7f6e76785c90>,
#   <matplotlib.lines.Line2D at 0x7f6e76737890>,
#   <matplotlib.lines.Line2D at 0x7f6e76737d90>,
#   <matplotlib.lines.Line2D at 0x7f6e76747710>,
#   <matplotlib.lines.Line2D at 0x7f6e76747c10>,
#   <matplotlib.lines.Line2D at 0x7f6e76759590>,
#   <matplotlib.lines.Line2D at 0x7f6e76759a90>,
#   <matplotlib.lines.Line2D at 0x7f6e7674eb90>,
#   <matplotlib.lines.Line2D at 0x7f6e76767890>,
#   <matplotlib.lines.Line2D at 0x7f6e76760e90>,
#   <matplotlib.lines.Line2D at 0x7f6e766f86d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f6e767da890>,
#   <matplotlib.lines.Line2D at 0x7f6e7676ded0>,
#   <matplotlib.lines.Line2D at 0x7f6e7677cd10>,
#   <matplotlib.lines.Line2D at 0x7f6e7678cc10>,
#   <matplotlib.lines.Line2D at 0x7f6e7679ea90>,
#   <matplotlib.lines.Line2D at 0x7f6e76730910>,
#   <matplotlib.lines.Line2D at 0x7f6e7673e7d0>,
#   <matplotlib.lines.Line2D at 0x7f6e7674e650>,
#   <matplotlib.lines.Line2D at 0x7f6e76796b90>,
#   <matplotlib.lines.Line2D at 0x7f6e767a5f50>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f6e7676d9d0>,
#   <matplotlib.lines.Line2D at 0x7f6e7677c810>,
#   <matplotlib.lines.Line2D at 0x7f6e7678c710>,
#   <matplotlib.lines.Line2D at 0x7f6e7679e590>,
#   <matplotlib.lines.Line2D at 0x7f6e7679ef10>,
#   <matplotlib.lines.Line2D at 0x7f6e76730e90>,
#   <matplotlib.lines.Line2D at 0x7f6e7673ed10>,
#   <matplotlib.lines.Line2D at 0x7f6e76759f90>,
#   <matplotlib.lines.Line2D at 0x7f6e76767d90>,
#   <matplotlib.lines.Line2D at 0x7f6e766f8bd0>],
#  'fliers': [],
#  'means': []}

# %% [markdown]
# # Regrets

# %%
times = range(len(file))
plt.plot(times,regretsRandom)
plt.plot(times, regretsStatic,times ,regretsOptimal,times, regretsUcb, regretslinUcb)
plt.legend(["random", "static", "optimale", "UCB", "linUCB"])
