# %%
from policy_finder import *
from Agent import *

# %%
plt.rcdefaults()
distri = {0: -0.001, 3: 1, 4: 1, 5: -1, 6: -1}
episodes, rewards_value, iterations_value, fig = test_agent(plan= "7", episode_count= 500,mode="ValueIteration", alpha=0.001, gamma= 0.99, distri = distri)
# Out:
# Episode : 0 rsum=1.0020000000001064, 1001 actions
# Episode : 1 rsum=1.0020000000001081, 1001 actions
# Episode : 2 rsum=2.957000000000004, 48 actions
# Episode : 3 rsum=1.002000000000105, 1001 actions
# Episode : 4 rsum=1.0020000000001086, 1001 actions
# Episode : 5 rsum=1.0020000000001081, 1001 actions
# Episode : 6 rsum=1.0020000000001086, 1001 actions
# Episode : 7 rsum=1.0020000000001081, 1001 actions
# Episode : 8 rsum=1.0020000000001086, 1001 actions
# Episode : 9 rsum=1.0020000000001055, 1001 actions
# Episode : 10 rsum=1.9480000000000004, 56 actions
# Episode : 11 rsum=1.0020000000001081, 1001 actions
# Episode : 12 rsum=1.0020000000001072, 1001 actions
# Episode : 13 rsum=1.002000000000105, 1001 actions
# Episode : 14 rsum=2.911000000000007, 94 actions
# Episode : 15 rsum=1.002000000000106, 1001 actions
# Episode : 16 rsum=1.0020000000001064, 1001 actions
# Episode : 17 rsum=1.002000000000109, 1001 actions
# Episode : 18 rsum=1.002000000000109, 1001 actions
# ...

# %%
plt.rcdefaults()
fig

# %%
sns.set()
plt.clf()
plt.plot(episodes, rewards_value.cumsum()/episodes)
#plt.legend(["Value Iteration", "Policy Iteration"])
plt.xlabel("Episode")
plt.ylabel("Gain cumulé moyen")
# Out:
# Text(0, 0.5, 'Gain moyen')

# %%
sns.set()
plt.clf()
plt.plot(episodes, iterations_value.cumsum()/episodes)
#plt.legend(["Value Iteration", "Policy Iteration"])
plt.xlabel("epidoses")
plt.ylabel("Nombre d'actions moyen")
# Out:
# Text(0, 0.5, "Nombre d'actions moyen")

# %%
fig, ax= plt.subplots()
ax.boxplot([rewards_value,rewards_policy], sym="")
ax.set_xticklabels(["Value Iteration", "Policy Iteration"])
plt.ylabel("Gains")
# Out:
# Text(0, 0.5, 'Gains')

# %%
fig, ax= plt.subplots()
ax.boxplot([iterations_value,iterations_policy], sym="")
ax.set_xticklabels(["Value Iteration", "Policy Iteration"])
plt.ylabel("Nombre d'actions")
# Out:
# Text(0, 0.5, "Nombre d'actions")
