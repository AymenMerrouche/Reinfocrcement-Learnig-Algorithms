# %%
from policy_finder import *
from Agent import *
import matplotlib.pyplot as plt

# %%
plt.rcdefaults()
distri = {0: -0.001, 3: 1, 4: 1, 5: -1, 6: 0}
episodes, rewards_value, iterations_value, fig = test_agent(plan= "7", episode_count= 300,mode="ValueIteration", alpha=0.0001, gamma= 0.99, distri = distri)
a = 2
# Out:
# Episode : 0 rsum=3.9100000000000033, 95 actions
# Episode : 1 rsum=3.932000000000006, 73 actions
# Episode : 2 rsum=3.930000000000006, 75 actions
# Episode : 3 rsum=3.954000000000004, 51 actions
# Episode : 4 rsum=3.9230000000000054, 82 actions
# Episode : 5 rsum=3.9050000000000074, 100 actions
# Episode : 6 rsum=0.9569999999999999, 46 actions
# Episode : 7 rsum=3.946000000000005, 59 actions
# Episode : 8 rsum=3.9200000000000066, 85 actions
# Episode : 9 rsum=3.9200000000000035, 85 actions
# Episode : 10 rsum=3.859000000000009, 146 actions
# Episode : 11 rsum=3.944000000000005, 61 actions
# Episode : 12 rsum=0.9889999999999999, 14 actions
# Episode : 13 rsum=3.921000000000007, 84 actions
# Episode : 14 rsum=3.931000000000005, 74 actions
# Episode : 15 rsum=3.925000000000007, 80 actions
# Episode : 16 rsum=3.9370000000000034, 68 actions
# Episode : 17 rsum=3.956000000000004, 49 actions
# Episode : 18 rsum=3.9310000000000063, 74 actions
# ...

# %%
fig

# %%
# Create some mock data
sns.set()
t = np.arange(0.01, 10.0, 0.01)
data1 = np.exp(t)
data2 = np.sin(2 * np.pi * t)

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Episode')
ax1.set_ylabel('Gain cumulé moyen', color=color)
ax1.plot(episodes, rewards_value.cumsum()/episodes, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Nombre d\'actions cumulé moyen', color=color)  # we already handled the x-label with ax1
ax2.plot(episodes, iterations_value.cumsum()/episodes, color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
fig, ax= plt.subplots()
ax.boxplot([iterations_value,iterations_policy], sym="")
ax.set_xticklabels(["Value Iteration", "Policy Iteration"])
plt.ylabel("Nombre d'actions")
# Out:
# Text(0, 0.5, "Nombre d'actions")
